# %%
import pandas as pd
test_df = pd.read_csv("C:\\Users\\yjoshi\\Desktop\\YJOSHI\\CR\\OCM-19958\\818_sodexo_2019.csv",sep=",",index_col=0)
test_df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
a =10
print (a)
# Out:
# 10
