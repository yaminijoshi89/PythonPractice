# %%
import pandas as pd
import numpy as np
import math 
cart_data = pd.read_csv("cartesian_data.csv")
#cart_data = np.loadtxt("cartesian_data.csv")


def cart2pol(x,y):
    r = np.sqrt(np.power(x,2)+np.power(y,2))
    theta = (np.arctan(y/x))*180/np.pi
    #theta = np.arctan(y,x)
    return(r,theta)

X,Y = cart2pol(cart_data["mean_corr"],cart_data["std_correlation"])
nd = pd.DataFrame()
nd["rho"] = X
nd["theta"] = Y
nd
# Out:
#           rho      theta
# 0    0.674268  20.828868
# 1    0.633552  26.626862
# 2    0.408768  18.145167
# 3    0.378852  23.895598
# 4    0.183836  38.723393
# 5    0.900441  30.168053
# 6    0.511865  22.780444
# 7    0.646547  32.995595
# 8    0.559480  44.816344
# 9    0.172978  38.125056
# 10   0.904339  49.171975
# 11   0.636685  36.164083
# 12   0.686216  27.907591
# 13   0.623848  49.741690
# 14   1.009836  41.617711
# 15   1.101980  38.413247
# 16   0.841416  53.715009
# 17   0.879366  34.035213
# 18   1.235432  47.020716
# 19   0.387944  22.437879
# 20   0.305085  11.340378
# 21   0.581405  25.264840
# 22   0.800738  36.416353
# 23   0.587595  29.218842
# 24   0.754511  41.794612
# 25   0.729835  27.142262
# 26   0.390762  32.767006
# 27   1.078887  38.872866
# 28   0.740763  29.211794
# 29   0.727744  33.096517
# ..        ...        ...
# 959  0.225223  10.675049
# 960  0.674111  42.909565
# 961  1.085549  36.765752
# 962  1.126128  48.609856
# 963  0.610244  31.442999
# ...
